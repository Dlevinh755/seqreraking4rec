# %%
import pandas as pd
df = pd.read_csv('data/preprocessed/beauty_min_rating3-min_uc20-min_sc20/dataset_single_export.csv')

# %%
import pandas as pd
pd.set_option("display.max_colwidth", None)  # hoặc -1 cho pandas cũ
print(df.head(1)["item_image_path"].to_string())
# Out:
# 0    data\preprocessed\beauty_min_rating3-min_uc20-min_sc20\images\item_B00AE07BC6_d247043d.jpg

# %%
df.shape
# Out:
# (5919, 8)

# %%
df.head(1)
# Out:
#       Item_id  user_id  item_new_id  \
# 0  B00AE07BC6        1           38
#
#                                                                  item_text  \
# 0  Axe 3 in 1 Shampoo Plus Conditioner Plus Bodywash Total Fresh, 12 Ounce
#
# ...
